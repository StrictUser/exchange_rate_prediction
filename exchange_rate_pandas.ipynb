# %%
import pandas as pd

# %%
df=pd.read_csv("usd4.csv")

# %%
df.describe()
# Out:
#               rate
# count  1778.000000
# mean     20.963740
# std       7.390856
# min       7.990000
# 25%      12.952500
# 50%      24.965000
# 75%      26.457500
# max      30.010000

# %%
df["rate"].min()
# Out:
# 7.99

# %%
df["rate"].max()
# Out:
# 30.01

# %%
df["rate_kop"] = df["rate"]*100

# %%
df
# Out:
#             date   rate  rate_kop
# 0     31.12.2013   7.99     799.0
# 1     30.12.2013   7.99     799.0
# 2     27.12.2013   7.99     799.0
# 3     26.12.2013   7.99     799.0
# 4     25.12.2013   7.99     799.0
# 5     24.12.2013   7.99     799.0
# 6     23.12.2013   7.99     799.0
# 7     20.12.2013   7.99     799.0
# 8     19.12.2013   7.99     799.0
# 9     18.12.2013   7.99     799.0
# 10    17.12.2013   7.99     799.0
# 11    16.12.2013   7.99     799.0
# 12    13.12.2013   7.99     799.0
# 13    12.12.2013   7.99     799.0
# 14    11.12.2013   7.99     799.0
# 15    10.12.2013   7.99     799.0
# 16    09.12.2013   7.99     799.0
# 17    06.12.2013   7.99     799.0
# 18    05.12.2013   7.99     799.0
# 19    04.12.2013   7.99     799.0
# 20    03.12.2013   7.99     799.0
# 21    02.12.2013   7.99     799.0
# 22    29.11.2013   7.99     799.0
# 23    28.11.2013   7.99     799.0
# 24    27.11.2013   7.99     799.0
# 25    26.11.2013   7.99     799.0
# ...

# %%
df["rate"].plot()
